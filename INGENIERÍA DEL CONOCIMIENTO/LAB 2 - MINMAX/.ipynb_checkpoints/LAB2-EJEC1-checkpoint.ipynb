# %% [markdown]
# # Laboratorio 2 - Ejercicio 1.
# ### Gonzalo de las Heras de Matías.
# ## Práctica de Búsqueda con Adversario.
#
# ### Objetivo
#
# Programar de forma autónoma dos <b>JUEGOS CON ADVERSARIO INTERACTIVOS</b>.
#
# Se trata de programar el algoritmo MiniMax y sus variaciones (decisiones imperfectas y poda α-β) de forma
# que el jugador pueda jugar contra el programa de forma real.
#
# #### Librerias

# %%
from NIM import Nim

# %% [markdown]
# #### Inicio del juego

# %%
nim = Nim(Profundidad_K=2)
nim.Jugar()
# Out:
# Introduzca número de fichas: 18
# Introduzca el primer jugador, Humano (H), Máquina (M): H
#
# ---------------------
# | COMIENZA EL JUEGO |
# ---------------------
#
# Quedan:  18 FICHAS.
# Turno del jugador:   H
# Se ha calculado la mejor jugada en:  0.0007498264312744141  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# ¿Cuántas fichas tomas?: 99
# Error
# ¿Cuántas fichas tomas?: 99
# Error
# ¿Cuántas fichas tomas?: -1
# Error
# ¿Cuántas fichas tomas?: 1
#
# ------------
#
# Quedan:  17 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.0003199577331542969  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  16 FICHAS.
# Turno del jugador:   H
# Se ha calculado la mejor jugada en:  0.0007159709930419922  s.
# El movimiento recomendado para el jugador es tomar:  3 FICHAS.
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  13 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.0001609325408935547  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  12 FICHAS.
# Turno del jugador:   H
# Se ha calculado la mejor jugada en:  0.0006937980651855469  s.
# El movimiento recomendado para el jugador es tomar:  3 FICHAS.
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  9 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.00016117095947265625  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  8 FICHAS.
# Turno del jugador:   H
# Se ha calculado la mejor jugada en:  0.0005121231079101562  s.
# El movimiento recomendado para el jugador es tomar:  3 FICHAS.
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  5 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  9.870529174804688e-05  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  4 FICHAS.
# Turno del jugador:   H
# Se ha calculado la mejor jugada en:  7.295608520507812e-05  s.
# El movimiento recomendado para el jugador es tomar:  3 FICHAS.
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  1 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  2.9087066650390625e-05  s.
# El movimiento recomendado para el jugador es tomar:  1 FICHAS.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  0 FICHAS.
# Turno del jugador:   H
#
# ----------------------------
# | HA GANADO EL JUGADOR,  H  |
# ----------------------------

# %%
nim.EstadisticasTiemposDeCalculo()
