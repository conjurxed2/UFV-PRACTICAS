# %% [markdown]
# # Laboratorio 2 - Ejercicio 1. NIM. Profundidad máxima 2**K siendo K=2.
# ### Gonzalo de las Heras de Matías.
# ## Práctica de Búsqueda con Adversario.
#
# ### Objetivo
#
# Programar de forma autónoma dos <b>JUEGOS CON ADVERSARIO INTERACTIVOS</b>.
#
# Se trata de programar el algoritmo MiniMax y sus variaciones (decisiones imperfectas y poda α-β) de forma
# que el jugador pueda jugar contra el programa de forma real.
#
# #### Librerias

# %%
from NIM import Nim

# %% [markdown]
# #### Inicio del juego

# %%
nim = Nim(Ayuda=False, Profundidad_K=2)
nim.Jugar()
# Out:
# Introduzca número de fichas: 20
# Introduzca el primer jugador, Humano (H), Máquina (M): H
#
# ---------------------
# | COMIENZA EL JUEGO |
# ---------------------
#
# Quedan:  20 FICHAS.
# Turno del jugador:   H
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  17 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.0004260540008544922  s.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  16 FICHAS.
# Turno del jugador:   H
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  13 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.0002989768981933594  s.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  12 FICHAS.
# Turno del jugador:   H
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  9 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.00031375885009765625  s.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  8 FICHAS.
# Turno del jugador:   H
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  5 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  0.00011992454528808594  s.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  4 FICHAS.
# Turno del jugador:   H
# ¿Cuántas fichas tomas?: 3
#
# ------------
#
# Quedan:  1 FICHAS.
# Turno del jugador:   M
# Se ha calculado la mejor jugada en:  5.698204040527344e-05  s.
# La máquina toma:  1 FICHAS.
#
# ------------
#
# Quedan:  0 FICHAS.
# Turno del jugador:   H
#
# ----------------------------
# | HA GANADO EL JUGADOR,  H  |
# ----------------------------

# %%
nim.EstadisticasTiemposDeCalculo()
