# %% [markdown]
# # Laboratorio 2 - Ejercicio 2.
# ### Gonzalo de las Heras de Matías.
# ## Práctica de Búsqueda con Adversario.
#
# ### Objetivo
#
# Programar de forma autónoma dos <b>JUEGOS CON ADVERSARIO INTERACTIVOS</b>.
#
# Se trata de programar el algoritmo MiniMax y sus variaciones (decisiones imperfectas y poda α-β) de forma
# que el jugador pueda jugar contra el programa de forma real.
#
# #### Librerias

# %%
from OTHELLO import Othello

# %% [markdown]
# #### Inicio del juego

# %%
othello = Othello(Profundidad_K=2, Ayuda=False)
othello.ImprimirCuadroDeJuego()

# %%
othello.Jugar()
# Out:
# Introduzca el primer jugador, Humano (H), Máquina (M): H
#
# ---------------------
# | COMIENZA EL JUEGO |
# ---------------------
#
# Turno del jugador:   H
# La puntuación es: 0
# Posición X: 3
# Posición Y: 1
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: 4
# Se ha calculado la mejor jugada en:  0.10721731185913086  s.
# La máquina coloca ficha en: [4, 1]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -2
# Posición X: 4
# Posición Y: 2
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: 2
# Se ha calculado la mejor jugada en:  0.09942078590393066  s.
# La máquina coloca ficha en: [2, 1]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -6
# Posición X: 1
# Posición Y: 0
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: 4
# Se ha calculado la mejor jugada en:  0.26799893379211426  s.
# La máquina coloca ficha en: [5, 2]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -6
# Posición X: 5
# Posición Y: 1
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: 16
# Se ha calculado la mejor jugada en:  0.3964200019836426  s.
# La máquina coloca ficha en: [5, 0]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -12
# Posición X: 2
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -6
# Se ha calculado la mejor jugada en:  0.3237299919128418  s.
# La máquina coloca ficha en: [1, 5]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -22
# Posición X: 3
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -16
# Se ha calculado la mejor jugada en:  0.06296873092651367  s.
# La máquina coloca ficha en: [2, 0]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -32
# Posición X: 1
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -22
# Se ha calculado la mejor jugada en:  0.08204197883605957  s.
# La máquina coloca ficha en: [0, 0]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -42
# Posición X: 3
# Posición Y: 0
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -34
# Se ha calculado la mejor jugada en:  0.14897608757019043  s.
# La máquina coloca ficha en: [4, 0]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -52
# Posición X: 1
# Posición Y: 2
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -48
# Se ha calculado la mejor jugada en:  0.10695409774780273  s.
# La máquina coloca ficha en: [0, 5]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -68
# Posición X: 0
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -54
# Se ha calculado la mejor jugada en:  0.07069897651672363  s.
# La máquina coloca ficha en: [0, 3]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -74
# Posición X: 1
# Posición Y: 3
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -70
# Se ha calculado la mejor jugada en:  0.04441118240356445  s.
# La máquina coloca ficha en: [2, 5]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -90
# Posición X: 1
# Posición Y: 1
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -80
# Se ha calculado la mejor jugada en:  0.02585911750793457  s.
# La máquina coloca ficha en: [3, 5]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -90
# Posición X: 4
# Posición Y: 5
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -78
# Se ha calculado la mejor jugada en:  0.013297080993652344  s.
# La máquina coloca ficha en: [0, 1]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -92
# Posición X: 4
# Posición Y: 3
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -88
# Se ha calculado la mejor jugada en:  0.0028297901153564453  s.
# La máquina coloca ficha en: [5, 3]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -104
# Posición X: 02
# Posición Y: 4
#
# Ya hay una ficha en esa casilla.
# Posición X: 4
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -98
# Se ha calculado la mejor jugada en:  0.0006861686706542969  s.
# La máquina coloca ficha en: [5, 5]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -130
# Posición X: 5
# Posición Y: 4
#
# Movimiento VÁLIDO.
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   M
# La puntuación es: -116
# Se ha calculado la mejor jugada en:  0.00010895729064941406  s.
# La máquina coloca ficha en: [0, 2]
#
# Movimiento VÁLIDO.
#
# ------------
#
# Turno del jugador:   H
# La puntuación es: -124
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-05d85ba93605> in <module>()
# ----> 1 othello.Jugar()
#
# ~/OneDrive - UFV/UFV Clases/4º Curso/INCO/LABORATORIOS/LAB 2 - MINMAX/PRACTICA 2/OTHELLO.py in Jugar(self)
#     928             if self.__TieneJugada(JUGADOR_HUMANO, self.__Cuadro) == False and self.__TieneJugada(JUGADOR_MAQUINA, self.__Cuadro) == False:
#     929                 # FIN DEL JUEGO
# --> 930                 self.__FinDelJuego()
#     931                 ganador = True
#     932             else:
#
# ~/OneDrive - UFV/UFV Clases/4º Curso/INCO/LABORATORIOS/LAB 2 - MINMAX/PRACTICA 2/OTHELLO.py in __FinDelJuego(self)
#     886         Función para imprimir los resultados del juego, una vez ha terminado.
#     887         """
# --> 888         puntuacionHumano, puntuacionMaquina = self.__GetNumFichasJugadores()
#     889
#     890         print("Jugador humano:", puntuacionHumano, "Jugador máquina:", puntuacionMaquina)
#
# TypeError: __GetNumFichasJugadores() missing 1 required positional argument: 'Cuadro'

# %%
othello.EstadisticasTiemposDeCalculo()
