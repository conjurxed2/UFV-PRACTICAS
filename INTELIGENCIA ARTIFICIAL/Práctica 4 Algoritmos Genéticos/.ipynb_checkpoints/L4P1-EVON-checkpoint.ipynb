# %% [markdown]
# # Laboratorio 4. Práctica 1 - Algoritmo Genético con mutaciones
# ## Preparación de entorno
# ### Gonzalo de las Heras
# ### Jorge de la Fuente

# %% [markdown]
# #### Importar librerías de código

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import random

from math import e
from time import time

# %% [markdown]
# #### Parámetros del algoritmo genérico

# %%
Target = "ANIMULA VAGULA BLANDULA" 
NPOB = 100
NGEN = 10000
Q = 0.95
NRES = 25
NSAMPLE = 50

# %%
# No tocar
ITAR_TARGET = len(Target)
T_Inicio = 0
T_Final = 0
T_TOTAL = 0
Parada = 0
Terminar_Evolucion = 0

Stats_num_coincidencias_max = np.zeros(1) 
Stats_num_coincidencias_max_porcentaje = np.zeros(1) 
Stats_num_coincidencias_medio = np.zeros(1)  
Stats_num_coincidencias_medio_porcentaje = np.zeros(1) 
Stats_num_targets = np.zeros(1) 
Stats_num_targets_porcentaje = np.zeros(1)

# %% [markdown]
# #### Variables globales

# %%
Alfabeto = np.array(["A","B","C","D","E","F","G","H","I",
                     "J","K","L","M","N","Ñ","O","P","Q",
                     "R","S","T","U","V","W","X","Y","Z"," "])
Poblacion = None
Fitness = np.zeros(NPOB)
Coincidencias = np.zeros(NPOB)
Generacion_Actual = 1
Num_Coincidencias_Max = 0

# %% [markdown]
# #### Funciones auxiliares

# %%
def ImprimirPorcentajePoblacion():
    porcentaje = 20
    num_individuos_a_imprimir = int(round(20 * NPOB / 100, 0))
    posiciones_aleatoras = random.sample(range(0, NPOB - 1), num_individuos_a_imprimir)
    print("= Muestra de " + str(20) + "% de individuos (" + str(num_individuos_a_imprimir) + "):")
    print("=====================================")
    for i in range (0, num_individuos_a_imprimir):
        print("= #" + str(i + 1) + ": '" + ImprimirCromosoma(Poblacion[posiciones_aleatoras[i]]) + "'")

# %%
def ImprimirPoblacion():
    print("==================================================")
    for i in range(0, NPOB):
        print("#" + str(i) + ": '" + ImprimirCromosoma(Poblacion[i]) + "'")

# %%
def GenerarPoblacion():    
    # Números aleatorios
    poblacion_numeros = np.random.randint(0, len(Alfabeto), size=len(Target) * NPOB)
    
    # Creación del array de la poblacion con caracter "_"
    poblacion = np.array(['_' for _ in range(len(Target) * NPOB)])
    
    # Cambiamos los números por las letras del alfabeto
    for i in range(0, len(Target) * NPOB):
        letra = Alfabeto[poblacion_numeros[i]].encode('utf8', 'ignore').decode('utf8')
        poblacion[i] = letra
        
    # Devuelve la array de la población con el shape correcto
    return poblacion.reshape(NPOB, len(Target))

# %%
def GetLetraConsenso(PosicionLetra):
    letra = ''
    coincidencias = np.zeros(Alfabeto.shape[0])
    for i in range (0, Poblacion.shape[0]):
        coincidencias[np.where(Alfabeto == Poblacion[i][PosicionLetra])] += 1
    letra_index = np.argmax(coincidencias)
    letra = Alfabeto[letra_index]
    return letra

def GetIndividuoConsenso():
    individuo_consenso = ""
    for i in range(0, ITAR_TARGET):
        individuo_consenso += GetLetraConsenso(i)  
    return individuo_consenso

# %%
def CalcularFitnessFrase(Frase):
    num_coincidencias = 0
    
    # Recorremos toda la frase buscando coincidencias con la frase TARGET
    for i in range(0, ITAR_TARGET):
        if (Target[i] == Frase[i]):
            num_coincidencias += 1
            
    # Devuelve el fitness (sin normalizar) y el número de coincidencias
    return e**(num_coincidencias - ITAR_TARGET) - e **(-1 * ITAR_TARGET), num_coincidencias

# %%
def CalcularFitnessNormalizadoPoblacion():
    
    # Cálculo del fitness    
    for i in range(0, NPOB):
        Fitness[i], Coincidencias[i] = CalcularFitnessFrase(Poblacion[i])
        
    # Cálculo del fitness normalizado    
    Num_Coincidencias_Max = np.max(Coincidencias)    
    
    for i in range(0, NPOB):
        Fitness[i] = Fitness[i] / (e**(Num_Coincidencias_Max - ITAR_TARGET) - e **(-1 * ITAR_TARGET))

# %%
def Replicar(Indice_Individuo):
    # Seleccionamos un individuo al azar para ser borrado
    indice_individuo_a_borrar = np.random.randint(0, NPOB)
    
    # Copiamos el cromosoma al nuevo individuo teniendo en cuenta el factor de calidad
    for i in range(0, ITAR_TARGET):
        if np.random.uniform(0, 1) > Q:
            # Mutación
            Poblacion[indice_individuo_a_borrar][i] = Alfabeto[np.random.randint(0, len(Alfabeto))]
        else:
            # Copia exacta
            Poblacion[indice_individuo_a_borrar][i] = Poblacion[Indice_Individuo][i]

# %%
def ImprimirCromosoma(Cromosoma):
    texto = ""
    for i in range(0, len(Cromosoma)):
        texto += Cromosoma[i]
    return texto

# %%
def GetCromosomasPerfectos():
    indices_cromosomas_perfectos = np.where(Coincidencias==ITAR_TARGET)[0]
    print("-----------------------------------------")
    print("- Cromosoma objetivo: (" + Target + ")")
    print("-----------------------------------------")
    print("- En la población hay (", len(indices_cromosomas_perfectos), ") individuos perfectos.")
    print("-----------------------------------------")
    print("- Son:")
    print("-----------------------------------------")   
    for i in range(0, len(indices_cromosomas_perfectos)):
        print("#", indices_cromosomas_perfectos[i], "Cromosoma: ")
        ImprimirCromosoma(Poblacion[indices_cromosomas_perfectos[i]])
        print("-----------------------------------------")

# %%
def EvolucionarPoblacion():
    # Individuo al azar
    primer_individuo = np.random.randint(0, NPOB)
    
    # Recorrido 1, primer_induviduo hasta el final de la población    
    for i in range(primer_individuo, NPOB):
        if Fitness[i] >= np.random.uniform(0, 1):
            # Se replica
            Replicar(i)
            CalcularFitnessNormalizadoPoblacion()
            
    # Recorrido 2, el inicio de la población hasta primer_induviduo     
    for i in range(0, primer_individuo):
        if Fitness[i] >= np.random.uniform(0, 1):
            # Se replica
            Replicar(i)     
            CalcularFitnessNormalizadoPoblacion()

# %%
def ImprimirReporte(Generacion_Actual):
    
    global Stats_num_coincidencias_max
    global Stats_num_coincidencias_max_porcentaje
    
    global Stats_num_coincidencias_medio
    global Stats_num_coincidencias_medio_porcentaje
    
    global Stats_num_targets
    global Stats_num_targets_porcentaje
    
    num_coincidencias_max = int(round(np.max(Coincidencias), 0))
    num_coincidencias_max_porcentaje = int(round((num_coincidencias_max * 100) / ITAR_TARGET, 0))
    
    num_coincidencias_medio = int(round(np.mean(Coincidencias), 0))
    num_coincidencias_medio_porcentaje = int(round((num_coincidencias_medio * 100) / ITAR_TARGET, 0))   
                                        
    num_targets = len(np.where(Coincidencias==ITAR_TARGET)[0])
    num_targets_porcentaje = int(round((num_targets / NPOB) * 100, 0))
    
    Stats_num_coincidencias_max = np.append(Stats_num_coincidencias_max, num_coincidencias_max)
    Stats_num_coincidencias_max_porcentaje = np.append(Stats_num_coincidencias_max_porcentaje, num_coincidencias_max_porcentaje)
    
    Stats_num_coincidencias_medio = np.append(Stats_num_coincidencias_medio, num_coincidencias_medio)
    Stats_num_coincidencias_medio_porcentaje = np.append(Stats_num_coincidencias_medio_porcentaje, num_coincidencias_medio_porcentaje)
    
    Stats_num_targets = np.append(Stats_num_targets, num_targets)
    Stats_num_targets_porcentaje = np.append(Stats_num_targets_porcentaje, num_targets_porcentaje)   
    
    print("==================================================")
    print("= Target: '"+ Target+"'")
    print("= Longitud Target: ", ITAR_TARGET)
    print("= Longitud Poblacion: ", NPOB)
    print("= Número Generaciones: ", NGEN)
    print("= Factor de Calidad: ", Q)
    print("==================================================")
    print("= Generacion Actual: ", Generacion_Actual)
    print("= Mejor Individuo: '" + ImprimirCromosoma(Poblacion[np.argmax(Coincidencias)]) + "'")
    print("= Nº Coincidencias máximo: ", num_coincidencias_max, " - ", num_coincidencias_max_porcentaje, "%")
    print("= Nº Coincidencias medio: ", num_coincidencias_medio, " - ", num_coincidencias_medio_porcentaje, "%")
    print("= Nº Targets: ", num_targets, " - ", num_targets_porcentaje, "%") 
    print("==================================================")
    print("==================================================")
    print("\n")

# %%
def ComprobarCriterioDeParada(Terminar_Evolucion_Num):
    num_targets = len(np.where(Coincidencias==ITAR_TARGET)[0])
    num_targets_porcentaje = int(round((num_targets / NPOB) * 100, 0))   
    
    if num_targets_porcentaje >= 20:
        Terminar_Evolucion_Num += 1
    else:
        Terminar_Evolucion_Num = 0
    return Terminar_Evolucion_Num

# %%
def ImprimirGraficas():
    plt.plot(Stats_num_coincidencias_max, label='num_coinci_max')
    plt.plot(Stats_num_coincidencias_medio, label='num_coinci_medio')
    plt.legend(loc='upper left')
    plt.show()
    
    plt.plot(Stats_num_coincidencias_max_porcentaje, label='num_coinci_max_porcentaje')
    plt.plot(Stats_num_coincidencias_medio_porcentaje, label='num_coinci_medio_porcentaje')
    plt.plot(Stats_num_targets_porcentaje, label='num_targets_porcentaje')
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# # Programa principal

# %%
T_Inicio = time()

print("Inicio del algorimo genético\n")

Poblacion = GenerarPoblacion()
print("==================================================")
print("= Población Inicial:")
print("==================================================")
ImprimirPoblacion()
print("==================================================")
CalcularFitnessNormalizadoPoblacion()

while(Terminar_Evolucion != 2 and Generacion_Actual < NGEN):
    
    EvolucionarPoblacion()
            
    Generacion_Actual += 1    
    
    if Generacion_Actual % NSAMPLE == 0:
        print("==================================================")        
        print("===================  NSAMPLE =====================")
        print("==================================================")
        ImprimirPorcentajePoblacion()        
        ImprimirReporte(Generacion_Actual)
        Terminar_Evolucion = ComprobarCriterioDeParada(Terminar_Evolucion)
        
    elif Generacion_Actual % NRES == 0:
        print("==================================================")        
        print("====================  NRES =======================")
        ImprimirReporte(Generacion_Actual)        
        Terminar_Evolucion = ComprobarCriterioDeParada(Terminar_Evolucion)
        
print("==================================================")        
print("====================  FINAL ======================")
print("==================================================")
    
T_Final = time()
T_TOTAL = T_Final - T_Inicio

print("Tiempo de evolución: ", round(T_TOTAL, 1), "seg.")
# Out:
# Inicio del algorimo genético
#
# ==================================================
# = Población Inicial:
# ==================================================
# ==================================================
# #0: 'IAFDDTYNRHDJCVMRXKKJIYJ'
# #1: 'QYHDUEHTQIWRXFEYHGZYVBÑ'
# #2: 'DPYOVKWUFMPNHGECÑFÑJSUL'
# #3: 'CDM UZPTDD MBAGFQPBWEIS'
# #4: 'MBHKSMSFEÑBMCHFDCOGYIZU'
# #5: 'TJECVRJRIDIXTYZF XRÑAJE'
# #6: 'UEOPR II XRKZLUDABNGDPÑ'
# #7: 'MDXHUAMZTJYVFYEKZJSTZCÑ'
# #8: 'SRTQMRGSCEÑ ZDÑGOJZMCV '
# #9: 'AGNTPPUWBHOJHVVYBWFE OK'
# #10: 'QHJQYLEOJRVKMSJIEWABOHÑ'
# #11: 'YYWQPMMÑIDCCPDNWFNBGKDÑ'
# #12: 'HYTEUFHGPXCGFSPJLJLGXCQ'
# #13: 'ÑQNLÑÑBWAKEJNRMR  BDQBX'
# #14: 'VQSOJDVBOEGCWREWNMCQNFD'
# #15: 'QCRANTEBNWCSHHYJBDQWTÑS'
# #16: 'SFZZIUEIYJGRXYHEYXZDFOÑ'
# #17: 'YTÑVHÑIRKLL UIGUADTZHHZ'
# #18: 'NUBXICZHPOYAÑXTDBPBÑDUC'
# #19: 'HSXDKPSPYPWY FHBIISYCSO'
# #20: 'IU MQZ NTMRKJXNHXQYWPSH'
# #21: 'PSX EBTQBNXQXKEKQAXTGIK'
# #22: 'EPDQDLKÑESKXJIMIRXAÑFGL'
# #23: 'HNVXKJZVX GMKFOKUIEXNÑY'
# #24: 'XNCVMNDÑUYAKBROKBXOHYUX'
# #25: 'LNÑODIHNVIYXLLKKXWCAK D'
# #26: 'VMCTGMICIEQJPAFEJO QDÑD'
# #27: 'LBTFEVUPWZTWVZVXPÑÑHRTD'
# #28: 'ETJWNDNMLCBDTOLSKMHÑDYV'
# #29: 'BÑXSFZEYJCP RNSVKQKGVYA'
# #30: 'RGSRCGYÑWAAUOIÑZSIANTW '
# #31: 'TAWSFHSRGCGLPGGPMUTRMAS'
# #32: 'PJFHIBÑTKIJVÑODUCGÑFTWY'
# #33: ' Q FRINNX IORKKVVDEQEMF'
# #34: 'ANBAZÑYJCCXKAQSYJPFHQZV'
# #35: 'HSZHOG FZFXBLHDRKBMK IO'
# #36: 'SRCOBZNWRFGUOLMFFEYNBPD'
# #37: 'WFBVUWCYARKGZGYHURGBÑQD'
# #38: 'PTGLAN ÑITYFZFIKEQ YTPV'
# #39: 'UOIMGBTICPOFV BPSKYUZGC'
# #40: 'DCUEDMV HNKYL MEUJS UZZ'
# #41: 'KTWDYYNMTPCRLMNHXYJRPWP'
# #42: 'CBHÑXMKTTOLM URXZÑEFCYA'
# #43: 'TXXCMLÑFXQJJNVSLBAWFKGV'
# #44: 'IKEXNGIZGATNPCULHEZQYV '
# #45: 'ÑXAZQXUARFKRTMNYXXBHZBO'
# #46: 'WSYTNFRYVVRQGKIQESCFZTV'
# #47: 'BFOTPWUBLM YFKYTAZDQWIC'
# #48: 'AMGOAIBWVGCISQQQÑQVPSSM'
# #49: 'JKUTJOIAETUBMLÑKRXHOANV'
# #50: 'JKRBRQKTPBFZGOCDWGLTVLL'
# #51: 'MFLULQBÑV BYMZKHMEZMIÑJ'
# #52: 'ÑWGGÑALPAÑDGCSYECÑPXKEI'
# #53: 'TCJSBZPPFYCS DAEKNDKKBS'
# #54: 'UHOOCVCGOUÑKTFNDKADUQWF'
# #55: 'UHFWIHVXO  LG JZEIPXHM '
# #56: 'TIKYQSAÑY BI BCXJVVMRA '
# #57: 'FAPDMADZMRCAICBQGFÑHKPP'
# #58: 'DPSXLD PMREYNRCSÑÑJSN J'
# #59: 'LSOKKY UIZSYRTFNAFNVSFU'
# #60: 'WSBZTKTEGECNMHMODOTRFBV'
# #61: 'JGOMKOIQFNPUHMZHFLFZFDC'
# #62: 'THJIBJDXFESSJOENLMBIMSF'
# #63: 'ZIKLUMH ELPYHOCGEURSDÑÑ'
# #64: 'ÑÑEXRÑMIPZQDJTBHOQHOA A'
# #65: ' S AYVZXHXTRHOZVDFGTASY'
# #66: 'HTFPGCHNZAAVÑMSNXAVLMZK'
# #67: 'ZUAFCRÑAJOK LFYMIJQSAL '
# #68: 'GEMMTXÑZCKL WZLQPCUJBÑG'
# #69: 'CDNH PYLRFVVXNA TGZÑSKF'
# #70: ' ZWSWG OOTJH EÑGRNXVWFB'
# #71: 'IUUTKUZKKEPXYEZXVOAMWGC'
# #72: 'CGPGOAEDÑXYDQYYZVENDWJB'
# #73: 'MILATOÑZKVBDUJBTBWDVVOJ'
# #74: 'CONCTFUAPIDETKSLAZRHGSN'
# #75: 'POLINSQAGYIAQÑILERFPMZQ'
# #76: 'BVISMLMBXUWT RDÑÑVSYWFC'
# #77: ' WNXXLVUQLIOWGZOÑORBQÑL'
# #78: 'NWVVQHÑSRCCJL JW SDCDRN'
# #79: 'BZBE NT  SDRMJCMFKIOSLJ'
# #80: 'TKVZAÑSYTLAPBHZDSWPPOMC'
# #81: 'BTGXOXLÑMMWDFVQRNLMRPNE'
# #82: 'ST ZESDLPVTEYCNNWJYCBVL'
# #83: ' RXG HPHUWWKCNCDCHBSFAI'
# #84: 'O SYZNPYUXPYAHJSVJFCTYZ'
# #85: 'ULTJWTJHDXXPPSZDSCOSIKT'
# #86: 'BVÑEPYSZVBYVRZQTM EGQGT'
# #87: 'DÑBCREOWYA LLTO KEZEÑKE'
# #88: 'N GPDX KBHIYÑUEJRRIRMDQ'
# #89: 'URMKSÑUJPYJMMD XUXHPERA'
# #90: 'JEDMBXGUYLOWMJSQEVZXDMA'
# #91: 'OXJDBUYCW QWMZTRDVAZAX '
# #92: 'ZKMWQPEVNJUXLAFTIÑBFQMG'
# #93: 'LXMRVQZFWECSYWCXXYVYSMO'
# #94: 'HBINGBYHHFWQKCLTTGZFAUX'
# #95: 'FETOABVFITDSLOÑGKCBVYEX'
# #96: 'DHVHKYSLCOGVQÑCCRC VZ U'
# #97: 'IPSNRBDIVDRLQTPWWF YVVF'
# #98: 'BUSMWCTZOHAHFUBRJILGGXM'
# #99: 'HCFYVGZQJJCQKRSÑMNORWFB'
# ==================================================
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  25
# = Mejor Individuo: 'CQNEBMA HLKULAJENJ DUQZ'
# = Nº Coincidencias máximo:  7  -  30 %
# = Nº Coincidencias medio:  5  -  22 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: ' QNEBXA VLKULA BLJ RUTT'
# = #2: 'MNCEDMAGVKTULA INRNÑUQ '
# = #3: 'HQNDEXA VLKULA BNJ RUTZ'
# = #4: 'MHCEPUA VKTULA BNIVGUQF'
# = #5: 'HQUEDMA VLTULA CMR RUMZ'
# = #6: 'MNCENMA VKTNLJ INJNRPQZ'
# = #7: 'MNCEDMA VKTULA INRNÑUQ '
# = #8: 'HQNQBXNRVLKULA BNJHRUTZ'
# = #9: 'MNCETMA VKTULA IKJNRUQG'
# = #10: 'MNCETMA AKTULA INTNOUQZ'
# = #11: 'OOMEBXA VLUULA BUJ EUTP'
# = #12: 'MNCEDMA VKTULA INRNÑUQ '
# = #13: 'MNCEDMA VNTULA WZJNRUQZ'
# = #14: 'HQN DPA VLTULA FNJ RUQÑ'
# = #15: 'MNCEDMA VKTULA IZJNRUQZ'
# = #16: 'MHCEPUA VKTULA BNIVGUQF'
# = #17: 'MNCEDMA VKTULL INENRUQZ'
# = #18: 'HQNEDMADVLTULA BMR RUQZ'
# = #19: 'NZLEDKAOVLTULAÑBNJ MUQK'
# = #20: ' QNEBXA VLKUUA BAJ RUTT'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  50
# = Mejor Individuo: 'MNCEDLA VKTULA IZJNZUOR'
# = Nº Coincidencias máximo:  11  -  48 %
# = Nº Coincidencias medio:  9  -  39 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  75
# = Mejor Individuo: 'BNCEU A VAGULA INZNRUAZ'
# = Nº Coincidencias máximo:  13  -  57 %
# = Nº Coincidencias medio:  11  -  48 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'BNCZUBANVAGULA INZFRUAR'
# = #2: 'BHCZUFA VAGULA ITZRRUÑG'
# = #3: 'BNOYUFAMVAGULAFITZNRUÑG'
# = #4: 'BNCLU A VAGYLA TNZNRUAT'
# = #5: 'BNCEU X VAGULA ANZNJULZ'
# = #6: 'JNCEU A VAGULA WNZNRUAZ'
# = #7: 'JNCEU A VAGULA INZNRUAZ'
# = #8: 'BSCÑWHA TAGULA INZNTUZZ'
# = #9: 'RNCZW A VZGULP INZNRCAG'
# = #10: 'BNCEU A VVGULA INZNJUSZ'
# = #11: 'NNCEZMA VCGULAERNZNYUAZ'
# = #12: 'BNCEU A VAGALA INZNJULZ'
# = #13: 'JNCEU A VAGULA INZNJUXZ'
# = #14: 'BNCEU ATVAGULA ANZOJULZ'
# = #15: 'BNCEU A VAFUCA ANZNJULZ'
# = #16: 'JNCEU C VAGULA INZNRUAZ'
# = #17: 'BNCOE A VAYULA INQNRUAZ'
# = #18: 'MNCEZMA VAGULAAIWZNLUAE'
# = #19: 'JNCEU A VAGULA INZNJUAZ'
# = #20: 'XCCEU A VAGULA KIZN UAZ'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  100
# = Mejor Individuo: 'BNCEU A VAGULA INZNJULZ'
# = Nº Coincidencias máximo:  14  -  61 %
# = Nº Coincidencias medio:  12  -  52 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  125
# = Mejor Individuo: 'BNTWULA VAGULA VNFNJULD'
# = Nº Coincidencias máximo:  15  -  65 %
# = Nº Coincidencias medio:  14  -  61 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'BNIQULA VAGULA INQNDULX'
# = #2: 'BNKWUFA VAGULA IMVNJULX'
# = #3: 'ENIEULA VAIULA IPVNDULE'
# = #4: 'BNIQULA VAGULA INQNDULX'
# = #5: 'BNIEULA VLGULA IDCNDULE'
# = #6: 'BNIQULA VWGULAUINLNDULE'
# = #7: 'BNIEULA RAGULA VNVNDULI'
# = #8: 'BNIQUTA VAGULA INQNDLLX'
# = #9: 'BNIEULA VAGULA INVNDUL '
# = #10: 'BNIQULA VAGULA INLNDULE'
# = #11: 'BNIEULA VWGULA IQVNDLL '
# = #12: 'BNIQULA VAGULA INLNDULE'
# = #13: 'ÑNIEULA VAGULA INVNDULI'
# = #14: 'BNIQULA VAGULA INQNDULZ'
# = #15: 'BNIEULA VGDULA INVNDULI'
# = #16: 'ENIEULA VAIULA IPVNDULE'
# = #17: 'BNIQULAKVAGULTMANQNDULX'
# = #18: 'BNIQUBA LAGUVA INQNDULX'
# = #19: 'BNIÑULA VAGULJ IDVNDULE'
# = #20: 'BNIQULA VAGUVA INQNDULX'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  150
# = Mejor Individuo: 'BNIEULA VAGULA INVNDULE'
# = Nº Coincidencias máximo:  17  -  74 %
# = Nº Coincidencias medio:  16  -  70 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  175
# = Mejor Individuo: 'YNIQULA VAGULA ALQNDULX'
# = Nº Coincidencias máximo:  18  -  78 %
# = Nº Coincidencias medio:  17  -  74 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'BNIQULA VAG LA FLQNDULA'
# = #2: 'ANIQULECVATULA ÑLQNDULA'
# = #3: 'ANIQULE VAGULA FLQNDILA'
# = #4: 'BNITULALVAGULAFFLQNDULQ'
# = #5: 'BNICULA VAGULA FLQNDULA'
# = #6: 'BNIQULA VAGULAKFLQNDULA'
# = #7: 'BNIQOLA VAGULA FLQNDULA'
# = #8: 'INIZULA VAGUUA FÑQNDULA'
# = #9: 'ANIQULE PAGULA FLQNDKLA'
# = #10: 'BNIDULA VAGULA ZYQDDULA'
# = #11: 'ENIQULE VAGULA FLQNDULA'
# = #12: ' NIQULA VAGUNK FLQNQULA'
# = #13: 'BNIQOLA VAGULA FLQNDULA'
# = #14: 'BNIIULL VAGULA FLWNDULA'
# = #15: 'BNIQULA VAGULA FLQNDULA'
# = #16: 'BNIQOLA VAGULA BLQNDULA'
# = #17: 'BÑIQULA VAGULA FLQNDULA'
# = #18: 'BNIIULA YAGULA BLQNDULR'
# = #19: 'BNIQULA VAGULA FJQNDDLA'
# = #20: 'JNIIULA YAGULA BLQNDULR'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  200
# = Mejor Individuo: 'BNIQULA VAGULA VLQNDULA'
# = Nº Coincidencias máximo:  19  -  83 %
# = Nº Coincidencias medio:  18  -  78 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  225
# = Mejor Individuo: 'ANIDULA VAGULA FLANDULA'
# = Nº Coincidencias máximo:  21  -  91 %
# = Nº Coincidencias medio:  19  -  83 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'ANIDULA VAGULA ILANDELA'
# = #2: 'ANITULA VAGULA WLQNDULA'
# = #3: 'ANIDULA V GJLAIFLANDULN'
# = #4: 'ANIQULN VAGULA BLINDULA'
# = #5: 'ANIDULA VVGULA JLANDULA'
# = #6: 'ANIDUTA VAGULA MLANDULA'
# = #7: 'ANIDULA VAGULA FLANDULA'
# = #8: 'ANIDULA VAGULA FLANDHLA'
# = #9: 'ANIDULC VAGULA FLANTULA'
# = #10: 'ANIDUWA VAGOLA FLANDULA'
# = #11: 'ANIDUOA WAGULA BLANDULA'
# = #12: 'ANIMULW VAGULA BFINDULA'
# = #13: 'ANIDULA VAGULA FLANDULA'
# = #14: 'ANIQULA VAGULE BLINDULA'
# = #15: 'GNIDUL  VAGULA FLANDULA'
# = #16: 'ANIDULA VAGHLA FLADDULA'
# = #17: 'ANIDULA AAGULA FLANDULA'
# = #18: 'ANIDULA VAGULA FLADDULA'
# = #19: 'ANIDULA PAGULA FLANDUMA'
# = #20: 'ANIQZLA VPGULAZFLQNDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  250
# = Mejor Individuo: 'ANIDULA VAGULA FLANDULA'
# = Nº Coincidencias máximo:  21  -  91 %
# = Nº Coincidencias medio:  20  -  87 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  275
# = Mejor Individuo: 'ANIDULA VAGULA FLANDULA'
# = Nº Coincidencias máximo:  21  -  91 %
# = Nº Coincidencias medio:  19  -  83 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'ANIQULX VAGULA YLANDULA'
# = #2: 'SNIQU A VADULA ILANXULA'
# = #3: 'ANIDULA VAGRLA TLANDULA'
# = #4: 'ANIMULA VAGULA MLANDULA'
# = #5: 'ANFDULH VACULA FLANDULI'
# = #6: 'ANIDULA AAGULA MLANDULA'
# = #7: 'ANIDULA VAGRKA FLANDULA'
# = #8: 'ANIQULA VAGULA YLANDULA'
# = #9: 'ANIDULAUVAGULA MFANDULA'
# = #10: 'ANIDUGA VAGULAHFLANDULA'
# = #11: 'ANIDULA VHGRRA FLANDULA'
# = #12: 'ANÑDULA VAGUPA MLANDULA'
# = #13: 'ANIDUGA VAGULA FLANDULA'
# = #14: 'ANIMULA VAGULA MLANDULA'
# = #15: 'ANIKULAMVAGULA MLANDULV'
# = #16: 'ANIQGLA VAGULARILANDULA'
# = #17: 'ANIK LA HYGULA MLANDULA'
# = #18: 'ANITULAHVAGULAVFLNNDULA'
# = #19: 'ANIMULA VAGULA XLANDULA'
# = #20: 'ANIDULA VAGULA MLANDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  300
# = Mejor Individuo: 'ANIMULA VAGULA MLANDULA'
# = Nº Coincidencias máximo:  22  -  96 %
# = Nº Coincidencias medio:  19  -  83 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  325
# = Mejor Individuo: 'ANIMULA VAGULA JLANDULA'
# = Nº Coincidencias máximo:  22  -  96 %
# = Nº Coincidencias medio:  20  -  87 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'ADHMULA VAGULA XLANDULA'
# = #2: 'ANIEULAJMAGULAKJLANDULA'
# = #3: 'ANIMULK NAGUHA XLANDULA'
# = #4: 'ATIMULAIVAGULA ILANDUJA'
# = #5: 'ANIMULA VACULA ILANGULB'
# = #6: 'ANIMULV VAGULA XLANDULA'
# = #7: 'ATIMULA VFGULA ALANDULA'
# = #8: 'ANIMULA VAGULA XWANDULA'
# = #9: 'ANIMUKA AAGULA XLANDUCA'
# = #10: 'ANIMULN VAGULA ILANDULA'
# = #11: 'ANIMULA VAGUWA ILNNDULA'
# = #12: 'ANIMULA VAGUWT ILNNDULA'
# = #13: 'ANIMUBSTVAGULAVILANDULA'
# = #14: 'ANIMULALVAGULA ILZNDULA'
# = #15: 'ANIMMHA VAGULA ILANDULA'
# = #16: 'ANIMULV VAGULAIXLANDULA'
# = #17: 'ANIMULA VAGULA ILANDTLA'
# = #18: 'ANIMULA VA ÑLA IEANDTLA'
# = #19: 'YNWMULA VAGULA ILANDULA'
# = #20: 'AKIMULA VAGULA ILANDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  350
# = Mejor Individuo: 'ANIMULA VAGULA ILANDULA'
# = Nº Coincidencias máximo:  22  -  96 %
# = Nº Coincidencias medio:  20  -  87 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  375
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  20  -  87 %
# = Nº Targets:  3  -  3 %
# ==================================================
# ==================================================
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'ANIMULA VAGULA BLANDULA'
# = #2: 'ANIMULA VAGULA BLAMDULA'
# = #3: 'ANIMULA VIGULP BLANDULA'
# = #4: 'ANIMULA VAGULA BLANDULA'
# = #5: 'ANIMULA VAGULA BLANNULA'
# = #6: 'ANIMULA VAGQLA BLANDULA'
# = #7: 'ANIMULA VAGULAVBLANJULA'
# = #8: 'JNIMUAA VAGUDA BLANDULA'
# = #9: 'DNIMULA VAGUAA BLANDULA'
# = #10: 'ANIMULA VAGUZANBLAZDULA'
# = #11: 'ANIMULA VAGULD BLANDUMA'
# = #12: 'ANIMUUA VAGULA XLANDULA'
# = #13: 'ANIMULA VAGULA BLANDULA'
# = #14: 'ANIMULA VZGULA PLANDULA'
# = #15: 'ANIMULA VAGULP BLANDULA'
# = #16: 'ANIMULA VAGUEA BLANDULA'
# = #17: 'ANIMULA VAUULATBLANDULA'
# = #18: 'ANIMULA VAGULA BLANWULA'
# = #19: 'ANIMULA VAGULA BLANDULA'
# = #20: 'ANIMULA VAGULA BLANDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  400
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  21  -  91 %
# = Nº Targets:  19  -  19 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  425
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  21  -  91 %
# = Nº Targets:  15  -  15 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (20):
# =====================================
# = #1: 'ANIMULA VAGULA BLANDULA'
# = #2: 'ANIMULA VAG LA BLANDULA'
# = #3: 'ANIFULA VAMULA BLANXURA'
# = #4: 'ANIMULA VAGULA BLANDYLA'
# = #5: 'ANIMULA VAGULA KLANDULA'
# = #6: 'ANIMULACVAGULA BFANDULA'
# = #7: 'ANIMULA VAGNLA BLANDULA'
# = #8: 'ANIMULA VAGULA BLANDULT'
# = #9: 'ANIMELG VAGULA BLANDULA'
# = #10: 'ANIMZLA VAGULA BLANDULA'
# = #11: 'ANIMULA VADULA BLDNDULA'
# = #12: 'ANIMULA VAGULA BLANDUAG'
# = #13: 'HNIMUL  VAGULAGBLANDULA'
# = #14: 'ANIMULA VAGULA BLANDULA'
# = #15: 'ANIMULA VAGULA BLANDULA'
# = #16: 'ANIMULLJVAGULA BRABDULA'
# = #17: 'UNIMULA VAGULA BLANDULA'
# = #18: 'ANIMULV VAGULA BLANNULA'
# = #19: 'ANIAULA VAGULA BRANDULA'
# = #20: 'ANUMULA VAGULAJBLANDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  450
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  21  -  91 %
# = Nº Targets:  22  -  22 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  100
# = Número Generaciones:  10000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  475
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  22  -  96 %
# = Nº Targets:  26  -  26 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  FINAL ======================
# ==================================================
# Tiempo de evolución:  32.2 seg.

# %%
ImprimirGraficas()
