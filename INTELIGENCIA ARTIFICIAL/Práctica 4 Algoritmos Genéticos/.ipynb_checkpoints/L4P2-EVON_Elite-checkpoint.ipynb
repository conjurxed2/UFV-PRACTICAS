# %% [markdown]
# # Laboratorio 4. Práctica 1 - Algoritmo Genético con mutaciones
# ## Preparación de entorno
# ### Gonzalo de las Heras
# ### Jorge de la Fuente

# %% [markdown]
# #### Importar librerías de código

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import random
import sys

from math import e
from time import time

# %% [markdown]
# #### Parámetros del algoritmo genérico

# %%
Target = "ANIMULA VAGULA BLANDULA" 
NPOB = 400
NGEN = 3000
Q = 0.95
NRES = 25
NSAMPLE = 50

if NPOB % 4 != 0:
    sys.exit("Error: La población no es múltiplo de 4.")

# %%
# No tocar
ITAR_TARGET = len(Target)
T_Inicio = 0
T_Final = 0
T_TOTAL = 0
Parada = 0
Terminar_Evolucion = 0

Stats_num_coincidencias_max = np.zeros(1) 
Stats_num_coincidencias_max_porcentaje = np.zeros(1) 
Stats_num_coincidencias_medio = np.zeros(1)  
Stats_num_coincidencias_medio_porcentaje = np.zeros(1) 
Stats_num_targets = np.zeros(1) 
Stats_num_targets_porcentaje = np.zeros(1)

# %% [markdown]
# #### Variables globales

# %%
Alfabeto = np.array(["A","B","C","D","E","F","G","H","I",
                     "J","K","L","M","N","Ñ","O","P","Q",
                     "R","S","T","U","V","W","X","Y","Z"," "])
Poblacion = None
Fitness = np.zeros(NPOB)
Coincidencias = np.zeros(NPOB)
Generacion_Actual = 1
Num_Coincidencias_Max = 0

# %% [markdown]
# #### Funciones auxiliares

# %%
def ImprimirPorcentajePoblacion():
    porcentaje = 20
    num_individuos_a_imprimir = int(round(20 * NPOB / 100, 0))
    posiciones_aleatoras = random.sample(range(0, NPOB - 1), num_individuos_a_imprimir)
    print("= Muestra de " + str(20) + "% de individuos (" + str(num_individuos_a_imprimir) + "):")
    print("=====================================")
    for i in range (0, num_individuos_a_imprimir):
        print("= #" + str(i + 1) + ": '" + ImprimirCromosoma(Poblacion[posiciones_aleatoras[i]]) + "'")

# %%
def ImprimirPoblacion():
    print("==================================================")
    for i in range(0, NPOB):
        print("#" + str(i) + ": '" + ImprimirCromosoma(Poblacion[i]) + "'")

# %%
def GenerarPoblacion():    
    # Números aleatorios
    poblacion_numeros = np.random.randint(0, len(Alfabeto), size=len(Target) * NPOB)
    
    # Creación del array de la poblacion con caracter "_"
    poblacion = np.array(['_' for _ in range(len(Target) * NPOB)])
    
    # Cambiamos los números por las letras del alfabeto
    for i in range(0, len(Target) * NPOB):
        letra = Alfabeto[poblacion_numeros[i]].encode('utf8', 'ignore').decode('utf8')
        poblacion[i] = letra
        
    # Devuelve la array de la población con el shape correcto
    return poblacion.reshape(NPOB, len(Target))

# %%
def GetLetraConsenso(PosicionLetra):
    letra = ''
    coincidencias = np.zeros(Alfabeto.shape[0])
    for i in range (0, Poblacion.shape[0]):
        coincidencias[np.where(Alfabeto == Poblacion[i][PosicionLetra])] += 1
    letra_index = np.argmax(coincidencias)
    letra = Alfabeto[letra_index]
    return letra

def GetIndividuoConsenso():
    individuo_consenso = ""
    for i in range(0, ITAR_TARGET):
        individuo_consenso += GetLetraConsenso(i)  
    return individuo_consenso

# %%
def CalcularFitnessFrase(Frase):
    num_coincidencias = 0
    
    # Recorremos toda la frase buscando coincidencias con la frase TARGET
    for i in range(0, ITAR_TARGET):
        if (Target[i] == Frase[i]):
            num_coincidencias += 1
            
    # Devuelve el fitness (sin normalizar) y el número de coincidencias
    return e**(num_coincidencias - ITAR_TARGET) - e **(-1 * ITAR_TARGET), num_coincidencias

# %%
def CalcularFitnessNormalizadoPoblacion():    
    # Cálculo del fitness    
    for i in range(0, NPOB):
        Fitness[i], Coincidencias[i] = CalcularFitnessFrase(Poblacion[i])
        
    # Cálculo del fitness normalizado    
    Num_Coincidencias_Max = np.max(Coincidencias)    
    
    for i in range(0, NPOB):
        Fitness[i] = Fitness[i] / (e**(Num_Coincidencias_Max - ITAR_TARGET) - e **(-1 * ITAR_TARGET))

# %%
def Replicar(Individuo, Posicion):    
    # Copiamos el cromosoma al nuevo individuo teniendo en cuenta el factor de calidad
    for i in range(0, ITAR_TARGET):
        if np.random.uniform(0, 1) > Q:
            # Mutación
            Poblacion[Posicion][i] = Alfabeto[np.random.randint(0, len(Alfabeto))]
        else:
            # Copia exacta
            Poblacion[Posicion][i] = Individuo[i]

# %%
def ImprimirCromosoma(Cromosoma):
    texto = ""
    for i in range(0, len(Cromosoma)):
        texto += Cromosoma[i]
    return texto

# %%
def GetCromosomasPerfectos():
    indices_cromosomas_perfectos = np.where(Coincidencias==ITAR_TARGET)[0]
    print("-----------------------------------------")
    print("- Cromosoma objetivo: (" + Target + ")")
    print("-----------------------------------------")
    print("- En la población hay (", len(indices_cromosomas_perfectos), ") individuos perfectos.")
    print("-----------------------------------------")
    print("- Son:")
    print("-----------------------------------------")   
    for i in range(0, len(indices_cromosomas_perfectos)):
        print("#", indices_cromosomas_perfectos[i], "Cromosoma: ")
        ImprimirCromosoma(Poblacion[indices_cromosomas_perfectos[i]])
        print("-----------------------------------------")

# %%
def EvolucionarPoblacion():    
    padres = GetPadres()    
    padres_shape = padres.shape[0]
    for i in range(0, 4):
        for j in range(0, padres_shape):
            if i == 0:
                Poblacion[padres_shape*i+j] = padres[j]
            else:
                Replicar(Poblacion[j], padres_shape*i+j)
    
    CalcularFitnessNormalizadoPoblacion()

# %%
def GetPadres():
    # Cálculo del número de padres
    num_padres = int(round(25 * NPOB /100, 0))
    padres = np.array(['_' for _ in range(len(Target) * num_padres)])
    padres = padres.reshape(num_padres, len(Target))
    
    # Índices de los mejores individuos
    fitness_index = np.zeros(num_padres)
    
    for i in range(0, num_padres):
        mejor_individuo = np.argmax(Fitness)
        fitness_index[i] = mejor_individuo
        Fitness[mejor_individuo] = -1
        
    for i in range(0, num_padres):
        indice = int(fitness_index[i])
        padres[i] = Poblacion[indice]
        
    return padres

# %%
def ImprimirReporte(Generacion_Actual):
    
    global Stats_num_coincidencias_max
    global Stats_num_coincidencias_max_porcentaje
    
    global Stats_num_coincidencias_medio
    global Stats_num_coincidencias_medio_porcentaje
    
    global Stats_num_targets
    global Stats_num_targets_porcentaje
    
    num_coincidencias_max = int(round(np.max(Coincidencias), 0))
    num_coincidencias_max_porcentaje = int(round((num_coincidencias_max * 100) / ITAR_TARGET, 0))
    
    num_coincidencias_medio = int(round(np.mean(Coincidencias), 0))
    num_coincidencias_medio_porcentaje = int(round((num_coincidencias_medio * 100) / ITAR_TARGET, 0))   
                                        
    num_targets = len(np.where(Coincidencias==ITAR_TARGET)[0])
    num_targets_porcentaje = int(round((num_targets / NPOB) * 100, 0))
    
    Stats_num_coincidencias_max = np.append(Stats_num_coincidencias_max, num_coincidencias_max)
    Stats_num_coincidencias_max_porcentaje = np.append(Stats_num_coincidencias_max_porcentaje, num_coincidencias_max_porcentaje)
    
    Stats_num_coincidencias_medio = np.append(Stats_num_coincidencias_medio, num_coincidencias_medio)
    Stats_num_coincidencias_medio_porcentaje = np.append(Stats_num_coincidencias_medio_porcentaje, num_coincidencias_medio_porcentaje)
    
    Stats_num_targets = np.append(Stats_num_targets, num_targets)
    Stats_num_targets_porcentaje = np.append(Stats_num_targets_porcentaje, num_targets_porcentaje)   
    
    print("==================================================")
    print("= Target: '"+ Target+"'")
    print("= Longitud Target: ", ITAR_TARGET)
    print("= Longitud Poblacion: ", NPOB)
    print("= Número Generaciones: ", NGEN)
    print("= Factor de Calidad: ", Q)
    print("==================================================")
    print("= Generacion Actual: ", Generacion_Actual)
    print("= Mejor Individuo: '" + ImprimirCromosoma(Poblacion[np.argmax(Coincidencias)]) + "'")
    print("= Nº Coincidencias máximo: ", num_coincidencias_max, " - ", num_coincidencias_max_porcentaje, "%")
    print("= Nº Coincidencias medio: ", num_coincidencias_medio, " - ", num_coincidencias_medio_porcentaje, "%")
    print("= Nº Targets: ", num_targets, " - ", num_targets_porcentaje, "%") 
    print("==================================================")
    print("==================================================")
    print("\n")

# %%
def ComprobarCriterioDeParada(Terminar_Evolucion_Num):
    num_targets = len(np.where(Coincidencias==ITAR_TARGET)[0])
    num_targets_porcentaje = int(round((num_targets / NPOB) * 100, 0))   
    
    if num_targets_porcentaje >= 20:
        Terminar_Evolucion_Num += 1
    else:
        Terminar_Evolucion_Num = 0
    return Terminar_Evolucion_Num

# %%
def ImprimirGraficas():
    plt.plot(Stats_num_coincidencias_max, label='num_coinci_max')
    plt.plot(Stats_num_coincidencias_medio, label='num_coinci_medio')
    plt.legend(loc='upper left')
    print("Hay", len(Stats_num_coincidencias_max), "segmentos de información.")
    plt.show()
    
    plt.plot(Stats_num_coincidencias_max_porcentaje, label='num_coinci_max_%')
    plt.plot(Stats_num_coincidencias_medio_porcentaje, label='num_coinci_medio_%')
    plt.plot(Stats_num_targets_porcentaje, label='num_targets_%')
    plt.legend(loc='upper left')
    print("Hay", len(Stats_num_coincidencias_max_porcentaje), "segmentos de información.")
    plt.show()

# %% [markdown]
# # Programa principal

# %%
T_Inicio = time()

print("Inicio del algorimo genético\n")

Poblacion = GenerarPoblacion()
print("==================================================")
print("= Población Inicial:")
print("==================================================")
ImprimirPoblacion()
print("==================================================\n\n")
CalcularFitnessNormalizadoPoblacion()

while(Terminar_Evolucion != 2 and Generacion_Actual < NGEN):
        
    EvolucionarPoblacion()
            
    Generacion_Actual += 1    
    
    if Generacion_Actual % NSAMPLE == 0:
        print("==================================================")        
        print("===================  NSAMPLE =====================")
        print("==================================================")
        ImprimirPorcentajePoblacion()        
        ImprimirReporte(Generacion_Actual)
        Terminar_Evolucion = ComprobarCriterioDeParada(Terminar_Evolucion)
        
    elif Generacion_Actual % NRES == 0:
        print("==================================================")        
        print("====================  NRES =======================")
        ImprimirReporte(Generacion_Actual)        
        Terminar_Evolucion = ComprobarCriterioDeParada(Terminar_Evolucion)
        
print("==================================================")        
print("====================  FINAL ======================")
print("==================================================")
    
T_Final = time()
T_TOTAL = T_Final - T_Inicio

print("Tiempo de evolución: ", round(T_TOTAL, 1), "seg.")
# Out:
# Inicio del algorimo genético
#
# ==================================================
# = Población Inicial:
# ==================================================
# ==================================================
# #0: 'K SIJHRHKLIJOWRFVSNCBGX'
# #1: 'INUGSTXTLHYÑRMHNIJJFSQZ'
# #2: 'TDGFLMBHESEUIZMSEOPPJHI'
# #3: 'OTYMXHHUQMÑAPYGJIUVZTML'
# #4: 'NNEGHHSKGIÑDGTXXSHJLÑÑG'
# #5: 'XMHLIVGNAÑMPF EICMVLVEX'
# #6: 'TLAGQHÑHAAXUGVNHKKWCWYX'
# #7: 'MIJZZOTZJÑ BNC FIHÑ N Y'
# #8: 'YWQUBGUKSOATHFOBVXOCOSY'
# #9: 'NAGÑIYPLJQNPOFVTJU QAWZ'
# #10: 'BDVWWEGHZOPUCPARTCIÑEKI'
# #11: 'ÑICLHZYCYCWYJRZCNYYÑSYQ'
# #12: 'EDWCSNRDOJGOSTZFHK NINM'
# #13: 'RÑVAKEBLHJIFD PMKJÑBMXY'
# #14: 'XFSSHFEXXXIHPJYBTGFMBKW'
# #15: 'RWDVWÑOYBSSQYQXSSBROZQH'
# #16: 'SGQJEUVQÑTMQRCHNSHC KYB'
# #17: 'YUQLWIBBHERAH KVBUZEPYÑ'
# #18: 'XEGEHGNVYPGBOXQXAMÑETGO'
# #19: 'TLGKKTÑFJ AEKPOLM  JGQO'
# #20: 'IJQ EQCZMQPARSAGOZNÑWCF'
# #21: 'SNFÑQGPOLQGGVFWVGVVAOXM'
# #22: 'QQEIWFKBBVZDXSKYNGWTP K'
# #23: 'HNEBÑDJSNÑKSATVLEIUWKXE'
# #24: 'XLWWZÑAMRJTSWX WTJÑXFEV'
# #25: 'MJWICAIZFOV BBLLBRWGOFÑ'
# #26: 'MYULXNKBUYARYJISYH IEJU'
# #27: 'YHFDTFITIBDBETDEVMESRZD'
# #28: 'ZRGSCRJFIBIDGEMN WWHKQN'
# #29: 'ACQ JXDOGRQÑFRYEAGUZMVN'
# #30: 'ZXOKYBFÑIWKQDYQYDXEQUV '
# #31: 'JYMXWGROFNPQQÑDFXTIYNMX'
# #32: 'XYOBARNCGXN XYSQIESGTLB'
# #33: 'GJTZHSLFEQX DYVOZYDBOBW'
# #34: ' RODTSJMOIQÑCQÑWIEEUAWZ'
# #35: 'YIJFPXRUMYPGB NJITAXBEF'
# #36: 'ERXSCÑRTCKMÑCUIAPOYTMSM'
# #37: 'YAITONGBEÑKDZWMTMMICAÑB'
# #38: 'FD YMOYQZCZNKDFJTEO URR'
# #39: 'BI HJHIDCWLWJASYXVZVVRO'
# #40: 'NNXMQUXPYYÑRAHOSDGRCZXL'
# #41: 'JAYBÑAIZASNETXTXÑQATZTF'
# #42: 'JVAZDC VYOZVGUIQFLXNNSC'
# #43: 'JQUZENDPEUPYPLKMXZDNBÑU'
# #44: 'ÑEXULQPJRHENCGJLHNYFRWQ'
# #45: 'T QWRMHUKWCGWVRCK EHWTA'
# #46: 'SPNBZUHEQZQPKÑJCHÑGDYGZ'
# #47: 'CAUFXLHDSDODWLOBTKBAIJW'
# #48: 'PDZQDUXHJ UKFWNLFÑCDUXS'
# #49: 'RÑUFXYQKL MLKGURSOPSMXV'
# #50: 'GXU ROÑDSAZBQXRF VBPRYL'
# #51: 'UDDQDEEVKFXCJDXPSTLJBDN'
# #52: 'LOZFFFBNGVOXINUMGZFAZEB'
# #53: 'YEYBÑPLQZCIEPZHVSJQMQPC'
# #54: 'B HEEKZKLUZHKZLGOÑRPXSJ'
# #55: 'MZTUJVHZJYEBXTJCLUEUQXK'
# #56: ' VVWUGFQJRIIPMRUBÑKGYZA'
# #57: 'AZHEQVFLGSYTRIFS TEÑBEA'
# #58: 'DOXFFVMWYBCXGGBYOTÑZYÑR'
# #59: 'GLJRVJFPBFNBMUGQPWJÑZCP'
# #60: 'OIGRIVHYXNXATHDPXDKF   '
# #61: 'QMAISV WL BDBXUY NQHBÑH'
# #62: 'DTSHTCDBYÑÑVALCSBDFUWRW'
# #63: 'POLGIBOZOVLNDLCRSGZHZTQ'
# #64: 'TÑAQSTÑPGMIFDUCFTLCBWTA'
# #65: 'PGOIWMHZAPSBMICCPYUCA P'
# #66: 'MAUKMOXHMLDCSLQIW JUNDQ'
# #67: 'GIAÑAGWADZILYTIXMKEUKTP'
# #68: 'SBKSVNÑMVDDJTSQTFAGSMOQ'
# #69: 'LQAVGWAÑCZPRRDRUSGCAXXI'
# #70: 'WOEUODÑ CYCJOMIRPY TWCK'
# #71: 'ÑYYASCSEKAMYYJMNYQYJDDX'
# #72: 'DLZHJTLFÑCWVLKAXNZMKKXF'
# #73: 'BYYIRPMDPZYZR LJACRACPR'
# #74: 'EKMIKNNVRAUXBSXA MWFHSS'
# #75: 'PZNHKMGGBLJL JÑKTCWHSPÑ'
# #76: 'RPXFTEMAUFPPXMBNKAJJAUX'
# #77: 'WECUQCYQPSLTTRRMKPÑIIWI'
# #78: 'HXHGEB AJYDQÑSQKVEXEMFQ'
# #79: 'PHHZFPQDWRÑQTLÑÑFYBBTVÑ'
# #80: 'GFEANVLYUQZÑQNLVMGPYESZ'
# #81: 'INRVGIKQLGQKUGDBJJAEDDQ'
# #82: 'A OGCGPMYEPYSNEZOE TPUK'
# #83: 'LKYMABV NXNTR  UEOJELBJ'
# #84: 'BXCLHDONÑEIKPP GFZN DW '
# #85: 'JPCBADVWQ NLQICÑUOSWBRP'
# #86: 'ZABUDOT JCDLWXHMVORTVKI'
# #87: 'BÑSZEAVRUXWHGFOKNQ OMUP'
# #88: 'FKBXXZMWSNAYDHÑDTEOPCGG'
# #89: 'TLLDIAQÑGVQKOJSTRRDRXKB'
# #90: 'RMFGÑYWQQXEAPOVKDDMQKUR'
# #91: 'UGZÑEJ XWTRXHRSEFGNIZIZ'
# #92: 'ÑÑJZBÑOGMNVOLOOVWDTOÑA '
# #93: 'DÑGMYNFKTJBRLVPCGHNZCIY'
# #94: 'BLK  ÑFGCBZXKJBMDYIVHSH'
# #95: 'ÑURNQYZHDVFOÑAKGHUBIBCL'
# #96: 'TLQNJVVY TIUGOROÑTÑ GJC'
# #97: 'ÑBMDRPBORIFJRSBPYCIZWGL'
# #98: 'SVLKYHWOYVGQHJUBBDMJOCB'
# #99: 'FHGKFDENYCASNFTZMTR YMD'
# #100: 'PEMNPHNROGYZFLYVBYUÑAUB'
# #101: ' NQS AVK KJDQGSDAAPLQU '
# #102: 'PH LYIFPIEJIXAVLPFCHTDÑ'
# #103: 'HAORWHXORXIHNOBZKNCHOCC'
# #104: 'AYTIFOAQQ OZOFOEQF CQSI'
# #105: 'ATÑFNJOBWKUOYKDFIMASXAD'
# #106: 'NTCBIF ZAZUEUXAFFVSCYHE'
# #107: 'VXMOWBXWIJRSRBOYQNROZÑA'
# #108: 'ÑGIPFZXGMNRIKLDSF ULHVI'
# #109: 'LZEMOJBNCTAAXFZABSASCGP'
# #110: 'LVXJXLG XRIGWXRLTQUIDUT'
# #111: 'DGORZMUPWVHKUCTEJPKESXR'
# #112: 'L UYEQAIYXLMYUJTKIHEERE'
# #113: 'XCO BZ SPWIPCWMGCÑLCXSP'
# #114: 'TLBKWCSIWCXOKGHCHXGHWQN'
# #115: 'LWWPJAJMXAR FUXHXÑUERZÑ'
# #116: 'RW SGAWKIAQAEOWZOUFCPCO'
# #117: ' LYV ÑBTPTWFXEFSDCFLÑRI'
# #118: 'ZLY KZOMGRZEZYN ETLJSKL'
# #119: 'KXQJRO ACZKBOJOPEBZQPJM'
# #120: 'MG ÑQVEXGYLQUESPMCIB JF'
# #121: 'KZEQXCFFWCDDOHESCNBQBBW'
# #122: ' QHRWMXEMEPMWLLIZNCPGKO'
# #123: 'YRLWEÑYBHLHZWZTGEWDRYLR'
# #124: 'XYJIEKQWULOPRHPDZIQASKN'
# #125: 'YUBCZTHYISATYFKYRDJEDLM'
# #126: 'ZYZJU EEWQIANACJIHUTXVY'
# #127: 'HKLXKFPYUWXXUOEDZQYGÑXO'
# #128: 'MEBWRZMPQTFBZJFXPÑS ZBV'
# #129: 'ÑWBOHOBQOLFOCÑSWRYZVJCW'
# #130: 'IGHPGVRRSSÑMCZFODINHQGQ'
# #131: 'IPPOVOAWGEVÑVRREÑLEJBZK'
# #132: 'EYEWOXLWTTBFDPQLRJOVQ O'
# #133: 'DZIQLAALHIGYIRRZZRRHDLH'
# #134: 'HYPZAYQIYR NJ HÑHOEZXNW'
# #135: 'XWTVVCUAGAOSQKVIUEZZUEE'
# #136: 'IPGQNJUTK OÑHOF LOSZHMF'
# #137: 'TJKQHFDAMÑGAFUPYMJHHDPS'
# #138: 'HOKGMMHCNHLGRDKVZCM BYY'
# #139: 'GKZAZTPGGPLRGCHBBNOPJQO'
# #140: 'WMEVPUGWRQCQTSUYHSHZÑNT'
# #141: 'ILZÑIAOCPC FDNPPQJZHXWG'
# #142: 'CMOXVFFYÑWGLTWTPBDFÑEYL'
# #143: 'CNSKXRRDKRUIUFQUTJDLNPL'
# #144: 'PRÑQFMPVLUGXFAYJPFTVHEG'
# #145: 'PEPDEP  FJYIALTFNDA ZKY'
# #146: 'ZQTHSYPIISDYMJEQYRBHGDI'
# #147: 'XSNWYXKLGI NWSLYAHAUZK '
# #148: 'EOSJPWZFHFEJBEIOVJXTÑHN'
# #149: 'BCOJQZQQCJCVTINWAÑITKZK'
# #150: 'VNFWEAKTXMWLFSQHAIXONIF'
# #151: 'TWXTPM ÑORHQTJCVKDHWPVV'
# #152: 'ÑRUUDOEQGQNÑJISR ENLVEY'
# #153: 'BBCYEKYXXHTZDAUA LGYSHW'
# #154: 'AXMYDQNEQUOQPBJCIQWZR L'
# #155: 'DÑJZX LFÑVVIHL QREÑKETN'
# #156: 'IFZIMMSQDTWZZ B CJFOITU'
# #157: 'IPKBOBLPIRPIOKIHWOFUCNE'
# #158: 'ZITLRUVAVJSVWEWMGLCNSMA'
# #159: 'ZSROÑAETJAQMWGXQMUÑNMJE'
# #160: 'CDKRYKYOTMNGL QGSHU HLW'
# #161: 'MCSXCTRQKYC  MWV GTZGHX'
# #162: 'MLLNCSWENVDÑAXLUGONSGDH'
# #163: ' LTWKSTPLC AGPUY QUVGUÑ'
# #164: 'XMXRQBZJGSWQTNJKOXSQIGY'
# #165: 'ZXJZNQTÑIVQTFSBTPJIMZMF'
# #166: 'ZAUÑTRTQZLMSMYSOFÑATUVJ'
# #167: 'YOZAMSFCMYPSQQOVIAH DT '
# #168: ' YEDUJ JNNGSETMBFJAJTFP'
# #169: 'UMAAQCXIWDEYYDVMAJYZFUD'
# #170: 'EXYJGOIGS VSXWYFHP VREZ'
# #171: 'PMUOFCWDTLGJEVJEOSXCZZY'
# #172: 'CTVÑ  RKEUDTLDPCGHREYCI'
# #173: 'KEUGHDIFTWH HWÑCQLHNREI'
# #174: ' GTFYKHETMFOILRYVJTÑÑUJ'
# #175: 'ZUPXDWCBZCBTLYC GTWUB M'
# #176: 'LVSTYWLSPMYWZRHMA XHQRN'
# #177: 'JEGDÑGQYRZHÑXÑIPW EOCVA'
# #178: 'CEPRGVFWGLGHROMCBWYOQDU'
# #179: 'MNBXSMJVWAMXTPÑ ND MOLS'
# #180: 'EXASOBPIH OENQUJUEPDYHB'
# #181: 'HIURAUDMFGJRIBXVRAGKGLY'
# #182: 'YSUBNUUOMHZMBRXÑ CMOHOC'
# #183: 'FVDLDVWBDRNUPIZIWGAXQAB'
# #184: 'M EEJNCRPTXFXBLEOILKGHY'
# #185: 'LSUNJNZ OGIWAGEMÑIRAVDK'
# #186: 'EGQYPMYMXV QGMQRN AA ZJ'
# #187: 'UHXX FUQGTRBDVJOXINDSCV'
# #188: 'NQÑMPMÑQYLWGLTEVTQACIUK'
# #189: 'YFNQYIV LNUJUNULFBCFWÑQ'
# #190: 'ZIBUTMYRXNMTNJAHXKCUKSH'
# #191: ' VFVPSVSAQ LDTJLCLEVÑDW'
# #192: 'XMTDTAJXYMUCEJAEAZWJPQQ'
# #193: 'VRRGYÑ UTNCMBFÑÑXFXXYHD'
# #194: 'WKZUJC HUFINXRQIHWSÑNVQ'
# #195: 'ÑRDEUFZHBPBXJXIAOAWFFBJ'
# #196: 'QLQICKCRCGAFLFUQWLQÑOEL'
# #197: 'UHDWSPQJMMPEÑUMÑKXHHÑVT'
# #198: 'PÑYKAGZÑURWA IIGHAVCFQ '
# #199: 'IÑNMXZPBWLXKTTVQ LXTMRU'
# #200: 'DLCMZLFKEFNM ODKQ NI IV'
# #201: 'F UAJÑBJSBIVGP ZÑÑXCXAO'
# #202: 'FXAHTIMEKZPBZNAÑYQFSG  '
# #203: 'EFXBÑAVYXÑIBBFFEYFIYFKP'
# #204: 'WÑ ÑTZRÑ QUYFJXRFPRFUJJ'
# #205: 'MUPDUOISBMIOCEDPYYFJOGJ'
# #206: 'DXVADOCPFYAOYZHVPÑTNKEH'
# #207: 'MNFIY Ñ AMJAITÑWEVJCVKJ'
# #208: 'NVV BMSTVIKOSUZ  UNZNEF'
# #209: 'SGLXAJYBLIYDBSBVUVAANSX'
# #210: 'WRCVNHQBYINGCPNSVTVRWXE'
# #211: 'OOXHAXZ GULÑÑZSIMVFPGCU'
# #212: 'MFRGGTÑVWPZDJB QPGUPTLV'
# #213: 'RBGHRSONAQÑCWNKÑLYSMRXG'
# #214: 'OJMROJNFPXAZ ZRTYOVCQNL'
# #215: 'DEBYHUZCDPZQÑNIETPPVMWG'
# #216: 'LXFILIS LTWIEÑEFCSHPXEP'
# #217: 'DHZKATFYWTEGHÑGTW WJQUP'
# #218: 'NUBFGRNNBWVMBV QTMÑAZPX'
# #219: ' Q EPRTMB IJJE QDZMYSZI'
# #220: 'FTBFSZGOUIHLLWHABTV ICN'
# #221: 'WIZÑVEOKFDKEBZWOFYNÑK E'
# #222: 'IBSUBX BSEDILPTT UTGÑKT'
# #223: 'UWRNIUQU RTHHLDEYMZMJKF'
# #224: 'BOOULRCCNMKFAXKARNFMQZO'
# #225: 'JUFFQWLV NPAQAGVRGHPXJS'
# #226: 'ZNCBTOBIGTKYAYFYMEPSQTL'
# #227: 'PK  VUHÑEGTNFZHÑDPKXGYS'
# #228: 'KHRZVPÑRAWEH NMOOFFNINA'
# #229: 'TTUJRKHJYRTMBSAAFBKWATL'
# #230: 'PMQLNLVÑMZLPYDPZKDJ FLE'
# #231: 'UOXVUF VFZÑMHCLFGFMKHEC'
# #232: 'COJQDNTTRSDRHMLVQKNLN P'
# #233: 'XO YKSNLWXEIVJOZFFBEKUK'
# #234: 'ÑAKBXZ DHXPK PDUQZDLFAH'
# #235: 'ZRYOOPNKVOWEÑXP SCNEDÑO'
# #236: 'TNAVLR HBHKNC ZIWQKUFAK'
# #237: 'TOOVDAGAJJAÑSYDUHQAFWZG'
# #238: 'EEOQINUPHICBVRNLORVMDUT'
# #239: ' TP JVXKCGÑDILCJKSAAQNI'
# #240: 'QBNPV EZCUKTIFIXRSXQIDK'
# #241: 'GQAHTRTYIXJXXHAOKIGYGNO'
# #242: 'GWJ QWBZLRÑWPBMIIQÑEHS '
# #243: 'OGNIXAXELVVYMWXLÑS TVZE'
# #244: 'OMQQTRICZLJROVZRXSXPDYO'
# #245: 'XPÑSKMTVXSLAEPVÑFDÑ MET'
# #246: 'TVYMOKKLUIHEÑQA ZBPITQÑ'
# #247: ' WPLCKUGILVBQYMIDP VUVK'
# #248: 'L BDNPSFKLÑVYSZWZNEXQXO'
# #249: 'FZIXFYÑQDNNNJEJQQJÑKKIY'
# #250: 'AGÑOYEFTAXNQAQE YQMPVYC'
# #251: 'NQWNYUFPÑIEELNMXSMUHXEW'
# #252: 'UPSJQGPRMSLFKMHPRFWGCQM'
# #253: 'UHE ETRNUJKFUTRAEÑPQMLL'
# #254: 'ZURKHGXLLEOZXPBBGFRRFAD'
# #255: 'CQ ZJCGLIBUBUKVBL RXNKÑ'
# #256: 'HVAVIYWAMWPLQPC IFVLOOG'
# #257: 'DFPVSHKZYRREYXQIGUDAÑQR'
# #258: 'YSNMGDÑO  IGNWDWGKKWTME'
# #259: 'MBAULJERGVLXMJHALKKQTTA'
# #260: 'VJBROKOPBCZWÑSWPDIERUVB'
# #261: 'NJEJHORGMTGFLYMIKJMQGTL'
# #262: 'ZATGTPXCKANMQRJSYISRYEU'
# #263: 'GQEVKDXS RRFXBJNTTOGJÑH'
# #264: 'Y BCQDKGYZKHFOWWGWKZBQE'
# #265: ' NEFTOHÑWRSBDIBPKK GVMX'
# #266: 'HCEXKBLJZCGQYGCTZIVGJIU'
# #267: 'IXMYLKJDNDYKJWYKFXNINMU'
# #268: 'EF MHYOWXPXKOKYFLZSIRFF'
# #269: 'OQRMWKLIYZKHCYLMTGRZOWV'
# #270: 'ROYYOZPGMBGAIÑJHNVQOPUH'
# #271: ' RVIZOCÑTVDSIXVKV RXWSU'
# #272: 'CGBGPJDNZOBJBSTPDYUZOB '
# #273: 'YSFJCTYSÑSEÑD CKQB PUMX'
# #274: 'MLEAVVXSQXBDDNZK RMRSÑU'
# #275: 'IOSMPKWA EDNSLYLWPHZTÑX'
# #276: 'RJJIROGQCLYYFJTETDGYLHY'
# #277: 'ZEUUPBQMQJYEIGABSOISOAG'
# #278: 'VNEILFMLÑEWKIVIZODWR TT'
# #279: 'YBAHOTBQEQCDEACUYYWGFOR'
# #280: 'JW ZODOUBRTYCFX IDNFCWW'
# #281: 'HTTYÑMETÑXGUYVJDTPIXLSW'
# #282: 'ZE HREFIEZUBRDM CÑODTDP'
# #283: 'BPEGGHLOWVCCX ÑÑWPDZPKV'
# #284: 'CWDJXXDQJLVRGHQBDAZQLJY'
# #285: 'CGAUSXRHEWTAVSBIXWNKNJR'
# #286: 'IRLCSLWDABIZSGMCSWCDIKI'
# #287: 'OSFWBLKMJUGKKAKHÑAKTTRI'
# #288: 'KCYOFPVUXOUGXPZFOBDV  G'
# #289: 'WON KPBJMUGVHBPATZFROIH'
# #290: 'HLLWHLGZRRWIVIGÑNLSOCAÑ'
# #291: 'WVQGAT ZAÑOVLJ JFLFLYPC'
# #292: 'YJXVTÑAOÑXQVVYSDRYZN NS'
# #293: 'VXTFFTXQTFP A NVUYEREB '
# #294: 'LVCGIQRIGBGZNL YUKDILÑL'
# #295: 'ZIHNPTZHWYJDWXPWJHNVSKF'
# #296: 'SNÑTWRSBSRSJY ZÑZIXOYEQ'
# #297: 'NLI C BUHZKM FWEQNKNCOL'
# #298: 'IIGKCESYNSOEQBMJFUYFAKP'
# #299: 'KXGWFLRHEMCZKEÑMB MÑOAH'
# #300: 'XVRGXZQKVWWPIMDQXFLUHKH'
# #301: 'CIMDOZZXCX HXAUQ UÑHBVU'
# #302: 'LÑ QJVCVZKXQCÑJSXUPAR  '
# #303: 'OPEI HPDEIPSQFWJTWBÑEXS'
# #304: 'FAIEOAFBQWQAOMMY DTYGYE'
# #305: 'AA WIEGTFEJÑKLÑDÑFUHLMG'
# #306: 'XCÑOJUWSAXÑXNJQGUPPFMYJ'
# #307: 'LEZQNOJCDDHKÑ RIGOVKYGM'
# #308: 'GKVÑUXMTVAWVKMNDDNTQUÑJ'
# #309: 'LQAYKRQAR EKZKYBÑII GCB'
# #310: 'VYRSBHIJYLLSABIERBQNTGE'
# #311: 'BGWBEHIIMMRNDILZFTZÑPUO'
# #312: 'SHRDUZJCTONTQIIPVMGTWIZ'
# #313: 'FLKXKSVEURTUTODDEYYXJEQ'
# #314: 'FJXBD ILMQJRGUBÑQLSUBKA'
# #315: 'YMGDKUBZQOMWDYJKMKIEEDB'
# #316: 'VT KIYJDBFCQZCEHYTLLZER'
# #317: 'UBWCFJKEWIPTAQUVKSJGMXA'
# #318: 'HBMUGDMNQSDBXFQQD PMLWZ'
# #319: 'ÑVZKTHLJSHBH GHCECÑAYMH'
# #320: 'TFVAHXMDTEAGXUKQCKKB  Q'
# #321: 'NEPZUFJÑPEBVAISIKPMO DR'
# #322: 'Z ECÑEYOQBODSYSH ESDDGZ'
# #323: 'RAUSW UOGACUGIEPRJMYCLH'
# #324: 'IBWBRLYHWHNMIGNEKDUFUPQ'
# #325: 'MIEVYZZTSSDMXNUBTQ VDSK'
# #326: 'NTWYMC YHOHOESFDNFNXCMT'
# #327: 'IGKLJKLRKFWUSRTCKBBIQVS'
# #328: 'IGRJ ÑQZOYHLWRWEQWUXIOM'
# #329: 'NXILDZTK BÑKSMDMFFQHWQS'
# #330: 'UQY YDYCAUUEWM LMIZ TTG'
# #331: 'KE QSSUUOBSACMSTSKMKSXU'
# #332: 'CIDVTVZHUQUX VSUJO LPKX'
# #333: 'DÑCAAHBMQGMVNB IVVJEIOV'
# #334: 'ROCOJC FQHSRFWHKILHURRQ'
# #335: 'ÑÑWWN XZEJICTXGIUPFOYYQ'
# #336: 'AKEMWGSYHOVNWTZXOKXSYÑ '
# #337: 'DDKZUJVCUBCZBXVCDKVVNJD'
# #338: ' X VATYZMWEAWA DNAOVYFS'
# #339: 'VHWOLLRQBKLNGRVRNÑFUO P'
# #340: 'HQWTBDAÑPÑ SSBFTAWUÑKXH'
# #341: 'KSJUJBFAJBZÑUANNIKENFTR'
# #342: 'EAYNHJAAWGLCZJKWCKANDTP'
# #343: 'BLYHYYJGKRAKXÑTIYURZCD '
# #344: 'GEMTESBTSFKBKCDHNYPXHOV'
# #345: 'RDUNJ DKU OÑWVWNZGAEÑZZ'
# #346: 'AÑEWUUJMGLMPFWGVSDWIB J'
# #347: 'THGHQ IJFFWMTTBYMXWUXÑM'
# #348: 'HRZSIZQMNRXWZRJ VZVWKDR'
# #349: 'EDMPUKVKFRDFAS CXPTVÑYT'
# #350: 'MEYHDQIVYFONRSINQUOQUUL'
# #351: 'FWUTÑJWC YÑQSÑBNTLNBIXR'
# #352: 'RAEÑYAÑZLFGBMYVGXJEGSBP'
# #353: 'YPDQRYQWINOWCTFVRRO OOH'
# #354: 'BBAOCXOGWCKRWIECZMSXKXY'
# #355: 'PFMZNYFQZTEJKGKZLDDUAUS'
# #356: 'VQFQDBÑXOOZPD ÑKOCVÑOXM'
# #357: 'ÑYVQBGGGLLRKIGOQCKONMRM'
# #358: 'VVORFHYZLDZKCHZRHVJOÑHO'
# #359: 'XSMZDMVRXTNOQÑVWOPFUTFU'
# #360: 'ISGYTBNZKADZSZPIHÑW YSI'
# #361: 'ÑEIOCTAQCHQPYMUYJUYQRDB'
# #362: 'WRSFIÑ TLIZTTFSJMXVSACK'
# #363: 'RDFDSO HCMRYQERNYQYGM F'
# #364: 'QJWTDJRZ ÑDHXCEGCLDNKPA'
# #365: 'YGWQKDIQZPAWCCPOZDCZURI'
# #366: 'EZEHFNJTLF KUBEWÑ EUÑZQ'
# #367: 'AAUEBQWJZÑÑODJPONJBTPJK'
# #368: 'VÑAOBZÑOSXRWDJVBUJSDSYÑ'
# #369: 'ÑQQZPEPDJLRECDVFUVGPOLN'
# #370: 'J GNDWYMVTBYXAFLTUÑPVTN'
# #371: 'VWTKPZÑUYLIIIJHAIÑPBFLC'
# #372: 'LPBOVWUCMGQUXKNSIEINVHC'
# #373: 'X BPRNSDETTRGAÑHJSWNJC '
# #374: 'L  ONIWVCDGBLNXSICHKHYX'
# #375: 'DV MIXTSMLKRÑMZFALAFYJG'
# #376: 'GCHFZOCLEZLÑTÑK INZNEFZ'
# #377: 'XRJNÑEAUÑNFKAGJJCQGGJDE'
# #378: ' TGYNPSFKTHLWCÑINMKNQÑF'
# #379: 'YÑUFYERFQOBGXLMVH BRXPN'
# #380: 'NCFEFCSHCXUBPCJZNRKLFBM'
# #381: 'UPHGÑLGRK ZISPGMGBJSNUH'
# #382: 'MGLEWIBCA ZSZJKRAXOHALM'
# #383: 'OPHTAMXWRLTHRPDCYADMEAI'
# #384: 'JDCNÑQQIBCJMTMCAHBTBCBP'
# #385: 'QÑGWWFGHMORTHRGMUVEESFD'
# #386: 'BD FEKÑMHALCVTPSQIDX ÑW'
# #387: 'IRVAV KTYACAMPOQEQSÑOHT'
# #388: 'PZLQATDBWGLPFGNAFVMU  Q'
# #389: 'CLSRGNJVGNLXVICÑÑDX PJI'
# #390: 'ASVK PJWDAHMLOYLGQOIHJA'
# #391: 'HYETGCHKAQPLAOKMNJUPHYM'
# #392: 'NGAHCYPWJNECVYFZKVWWRQJ'
# #393: 'NBYXYRCUUMIÑDBSFICPRIPN'
# #394: 'Q SIIBHRQZQEKSZDIÑINL B'
# #395: 'MGVÑDHCSBENRRNGFWXTDRDM'
# #396: 'AN YVMFJXYRRDWKEÑUINACI'
# #397: 'VXQVQQFHRHDGVBFEZICO AV'
# #398: 'VLVJÑUADR SHD EEYSFKANX'
# #399: 'LJCQGQLJZWÑOFOQ VU HZVM'
# ==================================================
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  400
# = Número Generaciones:  3000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  25
# = Mejor Individuo: 'ÑVIMULVTVABUKA TDZNDUÑA'
# = Nº Coincidencias máximo:  13  -  57 %
# = Nº Coincidencias medio:  11  -  48 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (80):
# =====================================
# = #1: 'AVIMULA VABULA BLZNDYÑA'
# = #2: 'AVIMULI VABULA OLZNDYÑA'
# = #3: 'AVIMULNTVABUCA BLANDULA'
# = #4: 'ACIMULV VAZUKA BLANDUÑA'
# = #5: 'AVIMULNTVABUTA BLANDULA'
# = #6: 'ALIMULN VABUKABBLZNDULA'
# = #7: 'ANIMULVTVABUVA BLZNDULA'
# = #8: 'ANIMULH VAAUBA BLZNDUÑA'
# = #9: 'AVIMULN VABUKA BLZNDULA'
# = #10: 'ACIMULV VAAUKA EL NDUÑA'
# = #11: 'ANIMULVTVABZKA BLZNDULW'
# = #12: 'AVIMULNTVABBKA BLINDULA'
# = #13: 'ANIMULV VÑAWBA BLZNDUÑA'
# = #14: 'AVIMULNTVABUKA BLANDULA'
# = #15: 'AVIMULA VABULA BLZNDPÑA'
# = #16: 'ANIMULV VAAUBA BLZNDUÑA'
# = #17: 'ACIMULA VAAUÑAXBLZNDUÑA'
# = #18: 'ACIMULV VAAUKA BLANDUÑA'
# = #19: 'AVIMULNTVABBKA BLANDULA'
# = #20: 'ACIMULW VAAUKA BLANDUÑA'
# = #21: 'ANIMULV VAAUBA BLZNDUÑA'
# = #22: 'ANIMULV VAAUBA BQZNDUÑA'
# = #23: 'ACNMULA VAAUKA BLANDUÑA'
# = #24: 'ACIMULV VAAUKR BLANDUÑA'
# = #25: 'AVIMULZ VABUKA YLZNDULA'
# = #26: 'TCTMULA VAAUKA BLZND ÑA'
# = #27: 'AVIMULNFVABUKA BLZNDULA'
# = #28: 'AVIMULATVABUKA BLANDULA'
# = #29: 'AVIMULN VABUKA BLZNDULA'
# = #30: 'AVIMULA VABULO BLZNDYÑÑ'
# = #31: 'AVIMULA VABULA BLZNDYÑA'
# = #32: 'ACIMXLV VAAUKA BLANDUÑA'
# = #33: 'ACIMULA VAAUKA BLZNDUÑA'
# = #34: 'AVIMULATVABUKA BLANDULA'
# = #35: 'ANIMULVTVABUHA BLZNDULA'
# = #36: 'ACIMULA VAAUKA BLZNDUÑA'
# = #37: 'AVIMULNPVABUTA BLANDULA'
# = #38: 'AHIMULA VABULA BLZNDYÑA'
# = #39: 'ANIMULVTVABUKA BLZNDULA'
# = #40: 'AVIMULA VABULA BLZNDYÑA'
# = #41: 'AVIMULNTVABUTA BOANDULA'
# = #42: 'ICIMULA VAAUKA BLZNDUÑA'
# = #43: 'ANIMULT VAAUBA BLZNDUÑA'
# = #44: 'AVIMULA VABULA BLZNDYÑA'
# = #45: 'AVIMULA VABULA BLZNDYÑA'
# = #46: 'ANIMULCTVABULA BLZODUÑA'
# = #47: 'ACIMULA VAAUÑA BLZNDUÑA'
# = #48: 'ACIMULV VAAUKA BLPNDUÑA'
# = #49: 'AVIMULNTVABUKA BLANDULA'
# = #50: 'AVIMULNTVAOUTA BLANDULN'
# = #51: 'AVIMULNTVABUTA BLANDULA'
# = #52: 'AVIMULNTVABUKA BLANDULA'
# = #53: 'ACIMULV VAAULA BLZNDUÑA'
# = #54: 'AVIMULN VABUKA BLZNDULA'
# = #55: 'AVIMULNPVABUTA BLANDULA'
# = #56: 'ANIMXLCTVABULA BLZNDUÑA'
# = #57: 'ANIMULV VAAUBA BLZNDUÑA'
# = #58: 'ACIMULV VAAUKA BLANDUÑA'
# = #59: 'AHIMULA VABULA BLZNDYWA'
# = #60: 'AVIMULNTVABUTA BLANDULA'
# = #61: 'AVIMULNTVABUKA BLANDULA'
# = #62: 'AVIMULNHVABUKA BLANDULA'
# = #63: 'ANIMULV VAAUBA BLZNDUÑA'
# = #64: 'ACIMULA VAAUKA BLZNDUÑA'
# = #65: 'AVIMULAUVABULA ZLTNDYÑA'
# = #66: 'AVIMULNTVABUKA BLANDULA'
# = #67: 'AVIMULNTVABUKA BLANDULZ'
# = #68: 'ACIMULA VAAUKA TLZNSUÑA'
# = #69: 'AVIMULNPVABUTA BLANDULA'
# = #70: 'ACIMULV VAAUKA BHANDUÑA'
# = #71: 'ANIMULV VAAUBA BLZNDUÑA'
# = #72: 'AIIMULV VAAUFA BLZNDUÑA'
# = #73: 'AVIMULA VABULA BLZNDYÑA'
# = #74: 'AVIMULNTVABUKA BLANDULA'
# = #75: 'ALIMULN VABUKA BLBNDULA'
# = #76: 'ACIMULV VAIUKA BLANDUÑA'
# = #77: 'AVIMULA VABULA BLTNDYÑA'
# = #78: 'AVIMULNTVABUKA BLANDULA'
# = #79: 'ANIMULV VAAUBA BLZNVUÑA'
# = #80: 'AVIMULNTVABUKA BLANDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  400
# = Número Generaciones:  3000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  50
# = Mejor Individuo: 'AVIMULATVABUKA BLANDULA'
# = Nº Coincidencias máximo:  19  -  83 %
# = Nº Coincidencias medio:  17  -  74 %
# = Nº Targets:  0  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  400
# = Número Generaciones:  3000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  75
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  21  -  91 %
# = Nº Targets:  2  -  0 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ===================  NSAMPLE =====================
# ==================================================
# = Muestra de 20% de individuos (80):
# =====================================
# = #1: 'ANIMULA VAIULA BLANLULA'
# = #2: 'ANIMU A VAGULA BLANDULA'
# = #3: 'ANIMULA VAGULA BLANDULA'
# = #4: 'ANIMULA VAGULA BLANDULA'
# = #5: 'ANIMULA VAGULANBLANDULA'
# = #6: 'ANIMULA VAGULA QLANDULA'
# = #7: 'ANIMULA VAGULA BLANDULA'
# = #8: 'ANIMULA VAGULA BLANDULA'
# = #9: 'ANIMULA VWGULA BLBNDULA'
# = #10: 'ANIMULA VAGULA BLANDULA'
# = #11: 'ANIBULA VAGULT BLANDULA'
# = #12: 'ANIMULA VAGULA BLALDTLA'
# = #13: 'ANIMULA VAGULA BLANDULA'
# = #14: 'ANIMULA VAGULA BLANDULA'
# = #15: 'ANIMULA VAGULA BLANDULA'
# = #16: 'AIIMÑLA BAGULA BLANDULA'
# = #17: 'ANIMULA VAGULA BLANDULA'
# = #18: 'AHIMULAÑVAGULA BLANDULA'
# = #19: 'ACIMULA VAGULA BLANDULA'
# = #20: 'ANIMULA VAGULA BLANDULA'
# = #21: 'ANIMULA VAGULA BLANDULA'
# = #22: 'ANIMULA VAGULA BLAWDNLA'
# = #23: 'ANIMULA VAGULA BLANDULA'
# = #24: 'ANIMULA VAGULA BLANDYQA'
# = #25: 'ANOMULA VAGULA BLANBULA'
# = #26: 'ANIMULA VAGULA BLANDULA'
# = #27: 'ANIMUXA VAGULA BLANDULA'
# = #28: 'ANIMUVA VAGULA BLANDULA'
# = #29: 'YNIMULA VAGULA BLANDULA'
# = #30: 'ANIMULA VAGULA BLANDULA'
# = #31: 'ANIMULA VAGULA BLANDULA'
# = #32: 'ANIMULA VAGULA BLANDULA'
# = #33: 'ANIMULA VAGULA BLANDUXA'
# = #34: 'ANIMULA VAGULA BLANDULA'
# = #35: 'ANIBULA VAGULL BLANDULA'
# = #36: 'ANIMU A VAGULA BLANDULA'
# = #37: 'ANIMULA VAGULA BLANDULA'
# = #38: 'ANIMULA VAGULA BLANDUQA'
# = #39: 'ANIMULA VAGUGA BLANDTLA'
# = #40: 'ANIMULA VAGULW BLANDULA'
# = #41: 'ANIMUEA VAGULA BLANVULA'
# = #42: 'ANIMULA VAGULA BLSNDULA'
# = #43: 'ANIMULA VAGULA BLANDULA'
# = #44: 'ANIMULA VAGULA BLANDULA'
# = #45: 'ANIMULA VAGULA BLANDULA'
# = #46: 'ANIMULA VAGUXA BLANDULA'
# = #47: 'ANIMULA VAGULA BLANDULA'
# = #48: 'ANIMULA VAGULA BLANDULA'
# = #49: 'ANIMULA VAGULA BLANDULA'
# = #50: 'ANIMULA VAGULA BLANDULA'
# = #51: 'ANIMULA VAGULA BLANDULA'
# = #52: 'ANIÑULA VAGULA BLANDUGA'
# = #53: 'ANIMULA VAGULA BLANDULA'
# = #54: 'ANIMULA VAGULA BLANDULA'
# = #55: 'ANIMULA VAGULA BLANDULA'
# = #56: 'ANIMULA VAGULAWBLAADULA'
# = #57: 'ANIMULA VAGULA BLANDULA'
# = #58: 'ANIMULA VAGULA BLANDULA'
# = #59: 'ANIMULA WAGULA BLANDULA'
# = #60: 'ANIMKLA VAGULQ BLANDULA'
# = #61: 'ANIMUZA VAGUCAWBLNNDULA'
# = #62: 'ANIMULA VAGULA BLANDULA'
# = #63: 'ANIMULA VAGULA BLANDULA'
# = #64: 'AQIMULA VAGULA BLANDULA'
# = #65: 'ANIMULA VAGULA BLANDULA'
# = #66: 'AUIMULA VAGULA BLANDULA'
# = #67: 'ANIMULA VAGULA BLANÑULA'
# = #68: 'ANIMULA VAGULK BLANDULV'
# = #69: 'ANIMULA VAGULA BLANDUVA'
# = #70: 'ANIMU A VAGULA BLANDULA'
# = #71: 'ANIMULA VAGULA BLANDULA'
# = #72: 'ANIMULA VAGULA HLANDULA'
# = #73: 'ANIMXLA VAGULA BDANDNLA'
# = #74: 'ANIMDKA VAGULA BLANDULA'
# = #75: 'ANIMUKA VAGULA BQANDULA'
# = #76: 'ANIMULA VAGULA BLANDULA'
# = #77: 'AUIMULA VADULA BLANDUL '
# = #78: 'ANIMULA VAGULA BLANDULA'
# = #79: 'ANIMULA VAGULA BLANDULA'
# = #80: 'ANIMULA VAGULA BLCNDULA'
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  400
# = Número Generaciones:  3000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  100
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  22  -  96 %
# = Nº Targets:  199  -  50 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  NRES =======================
# ==================================================
# = Target: 'ANIMULA VAGULA BLANDULA'
# = Longitud Target:  23
# = Longitud Poblacion:  400
# = Número Generaciones:  3000
# = Factor de Calidad:  0.95
# ==================================================
# = Generacion Actual:  125
# = Mejor Individuo: 'ANIMULA VAGULA BLANDULA'
# = Nº Coincidencias máximo:  23  -  100 %
# = Nº Coincidencias medio:  22  -  96 %
# = Nº Targets:  202  -  50 %
# ==================================================
# ==================================================
#
#
# ==================================================
# ====================  FINAL ======================
# ==================================================
# Tiempo de evolución:  7.6 seg.

# %%
ImprimirGraficas()
# Out:
# Hay 6 segmentos de información.
# Hay 6 segmentos de información.
